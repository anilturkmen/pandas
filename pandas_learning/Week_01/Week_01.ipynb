# %%
import pandas as pd

# %%
df = pd.read_csv("movies_youtube_sentiments.csv")

# %%
df
# Out:
#                                      name  \
# 0     Harry Potter and the Goblet of Fire
# 1                  The 40-Year-Old Virgin
# 2                     Memoirs of a Geisha
# 3                       Pride & Prejudice
# 4                           Batman Begins
# ...                                   ...
# 1100                 Assassination Nation
# 1101                 Unfriended: Dark Web
# 1102   The Nutcracker and the Four Realms
# 1103                         Little Italy
# 1104                The Happytime Murders
#
#                                      trailer_link     video_id  \
# 0     https://www.youtube.com/watch?v=3EGojp4Hh6I  3EGojp4Hh6I
# 1     https://www.youtube.com/watch?v=YnDeJn-BX5Q  YnDeJn-BX5Q
# 2     https://www.youtube.com/watch?v=4L-xlmakQvc  4L-xlmakQvc
# 3     https://www.youtube.com/watch?v=Ur_DIHs92NM  Ur_DIHs92NM
# 4     https://www.youtube.com/watch?v=neY2xVmOfUM  neY2xVmOfUM
# ...                                           ...          ...
# ...

# %%
df.head(10)
# Out:
#                                   name  \
# 0  Harry Potter and the Goblet of Fire
# 1               The 40-Year-Old Virgin
# 2                  Memoirs of a Geisha
# 3                    Pride & Prejudice
# 4                        Batman Begins
# 5                          The Descent
# 6                   Brokeback Mountain
# 7                             Sin City
# 8                       V for Vendetta
# 9                     Wedding Crashers
#
#                                   trailer_link     video_id  \
# 0  https://www.youtube.com/watch?v=3EGojp4Hh6I  3EGojp4Hh6I
# 1  https://www.youtube.com/watch?v=YnDeJn-BX5Q  YnDeJn-BX5Q
# 2  https://www.youtube.com/watch?v=4L-xlmakQvc  4L-xlmakQvc
# 3  https://www.youtube.com/watch?v=Ur_DIHs92NM  Ur_DIHs92NM
# 4  https://www.youtube.com/watch?v=neY2xVmOfUM  neY2xVmOfUM
# 5  https://www.youtube.com/watch?v=CSYg7Z1KS_I  CSYg7Z1KS_I
# 6  https://www.youtube.com/watch?v=kMA30rThECg  kMA30rThECg
# ...

# %%
df.tail(10)
# Out:
#                                     name  \
# 1095               The Catcher Was a Spy
# 1096                   Welcome to Marwen
# 1097                       Bad Samaritan
# 1098                              Border
# 1099                              Gringo
# 1100                Assassination Nation
# 1101                Unfriended: Dark Web
# 1102  The Nutcracker and the Four Realms
# 1103                        Little Italy
# 1104               The Happytime Murders
#
#                                      trailer_link     video_id  \
# 1095  https://www.youtube.com/watch?v=W0XTxOs-_Os  W0XTxOs-_Os
# 1096  https://www.youtube.com/watch?v=W6dy7xQ8NeE  W6dy7xQ8NeE
# 1097  https://www.youtube.com/watch?v=2ZiNWzqll04  2ZiNWzqll04
# 1098  https://www.youtube.com/watch?v=QMs28A1s1OA  QMs28A1s1OA
# 1099  https://www.youtube.com/watch?v=MnKbM9Zxtn8  MnKbM9Zxtn8
# 1100  https://www.youtube.com/watch?v=d9qyOGEuLY4  d9qyOGEuLY4
# ...
